# %%
import pandas as pd

# %%
original_df = pd.read_csv("2022-2023_power.csv")
display(original_df.head())
display(original_df.info())
# Out:
#          日期  淨尖峰供電能力(MW)  尖峰負載(MW)  備轉容量(MW)  備轉容量率(%)  工業用電(百萬度)  民生用電(百萬度)  \
# 0  20220101        29007     25661      3346     13.04    329.548    212.867
# 1  20220102        29556     25915      3641     14.05    325.723    210.396
# 2  20220103        33160     29976      3184     10.62    368.458    237.999
# 3  20220104        32950     30330      2620      8.64    382.670    247.180
# 4  20220105        32961     30449      2512      8.25    387.567    250.343
#
#    核一#1(萬瓩)  核一#2(萬瓩)  核二#1(萬瓩)  ...   大觀二    明潭   碧海   立霧   龍澗   卓蘭   水里  \
# 0         0         0         0  ...  31.8  74.0  0.0  1.7  3.5  4.0  0.0
# 1         0         0         0  ...  37.7  69.3  0.0  1.6  2.9  1.8  0.0
# 2         0         0         0  ...  21.6  60.0  0.0  1.6  4.0  4.0  0.0
# 3         0         0         0  ...  30.1  64.1  0.0  1.6  2.5  1.8  0.0
# 4         0         0         0  ...  35.6  40.5  0.0  1.6  3.1  2.8  0.0
#
#    其他小水力  風力發電  太陽能發電
# 0   22.6  54.7    0.0
# ...

# %%
selected_columns = ["日期", "淨尖峰供電能力(MW)", "尖峰負載(MW)", "備轉容量(MW)"
                    , "備轉容量率(%)", "工業用電(百萬度)", "民生用電(百萬度)"]
df = original_df[selected_columns]
display(df.head())
display(df.drop("日期", axis=1).describe())
# Out:
#          日期  淨尖峰供電能力(MW)  尖峰負載(MW)  備轉容量(MW)  備轉容量率(%)  工業用電(百萬度)  民生用電(百萬度)
# 0  20220101        29007     25661      3346     13.04    329.548    212.867
# 1  20220102        29556     25915      3641     14.05    325.723    210.396
# 2  20220103        33160     29976      3184     10.62    368.458    237.999
# 3  20220104        32950     30330      2620      8.64    382.670    247.180
# 4  20220105        32961     30449      2512      8.25    387.567    250.343
#         淨尖峰供電能力(MW)      尖峰負載(MW)     備轉容量(MW)    備轉容量率(%)   工業用電(百萬度)  \
# count    396.000000    396.000000   396.000000  396.000000  396.000000
# mean   36092.507576  31750.000000  4299.686869   13.722980  367.921407
# std     4471.465956   4179.503585  1302.309302    4.403209   32.538933
# min    26200.000000  21459.000000  1316.000000    3.370000  259.930000
# 25%    32911.000000  29126.250000  3300.500000   10.400000  348.981250
# 50%    35125.500000  31024.500000  4155.500000   13.030000  371.485500
# ...
